# %%
import numpy
from galpy.orbit import Orbit
ts=numpy.linspace(0.,100.,1001)
o = Orbit([0.75, 0.05, 0.15, 0.7, 0.025, 0.9])

from galpy.potential import MWPotential2014
from galpy.potential import PerfectEllipsoidPotential, NFWPotential, TriaxialNFWPotential

pot = TriaxialNFWPotential(
    amp=1.0,
    a=1.0,
    b=0.8,
    c=0.6
)

ppot = PerfectEllipsoidPotential()
sphere_pot = NFWPotential()

from galpy.actionAngle import estimateDeltaStaeckel, estimateAlphaBetaGammaStaeckel
from galpy.actionAngle import actionAngleStaeckel, actionAngleTriaxialStaeckel
from galpy.actionAngle import actionAngleStaeckelSingle, actionAngleTriaxialStaeckelSingle
#aAS= actionAngleStaeckel(pot=MWPotential2014,delta=0.4,c=False)

# %%
aAS = actionAngleStaeckelSingle(o.R(),o.vR(),o.vT(),o.z(),o.vz(), o.phi(), pot=tri_pot, delta = 0.0004, c = False)
#aAS.JR(), aAS.Jphi(), aAS.Jz()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'NoneType' object has no attribute 'cos'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 aAS = actionAngleStaeckelSingle(o.R(),o.vR(),o.vT(),o.z(),o.vz(), o.phi(), pot=tri_pot, delta = 0.0004, c = False)
#       2 #aAS.JR(), aAS.Jphi(), aAS.Jz()
#
# File ~/galpy/galpy/actionAngle/actionAngleStaeckel.py:678, in actionAngleStaeckelSingle.__init__(self, *args, **kwargs)
#     670 self._pux = self._delta * (
#     671     self._vR * self._coshux * self._sinvx
#     672     + self._vz * self._sinhux * self._cosvx
#     673 )
#     674 self._pvx = self._delta * (
#     675     self._vR * self._sinhux * self._cosvx
#     676     - self._vz * self._coshux * self._sinvx
#     677 )
# --> 678 EL = self.calcEL()
#     679 self._E = EL[0]
#     680 self._Lz = EL[1]
#
# File ~/galpy/galpy/actionAngle/actionAngleStaeckel.py:907, in actionAngleStaeckelSingle.calcEL(self, **kwargs)
#     889 def calcEL(self, **kwargs):
#     890     """
#     891     Calculate the energy and angular momentum.
#     892
#    (...)    905     - 2012-11-27 - Written - Bovy (IAS)
#     906     """
# --> 907     E, L = calcELStaeckel(self._R, self._vR, self._vT, self._z, self._vz, self._pot)
#     908     return (E, L)
#
# File ~/galpy/galpy/actionAngle/actionAngleStaeckel.py:1249, in calcELStaeckel(R, vR, vT, z, vz, pot, vc, ro)
#    1215 def calcELStaeckel(R, vR, vT, z, vz, pot, vc=1.0, ro=1.0):
#    1216     """
#    1217     Calculate the energy and angular momentum.
#    1218
#    (...)   1246
#    1247     """
#    1248     return (
# -> 1249         _evaluatePotentials(pot, R, z) + vR**2.0 / 2.0 + vT**2.0 / 2.0 + vz**2.0 / 2.0,
#    1250         R * vT,
#    1251     )
#
# File ~/galpy/galpy/potential/Potential.py:1941, in _evaluatePotentials(Pot, R, z, phi, t, dR, dphi)
#    1939 def _evaluatePotentials(Pot, R, z, phi=None, t=0.0, dR=0, dphi=0):
#    1940     """Raw, undecorated function for internal use"""
# -> 1941     return Pot._call_nodecorator(R, z, phi=phi, t=t, dR=dR, dphi=dphi)
#
# File ~/galpy/galpy/potential/Potential.py:212, in Potential._call_nodecorator(self, R, z, phi, t, dR, dphi)
#     210 if dR == 0 and dphi == 0:
#     211     try:
# --> 212         rawOut = self._evaluate(R, z, phi=phi, t=t)
#     213     except AttributeError:  # pragma: no cover
#     214         raise PotentialError(
#     215             "'_evaluate' function not implemented for this potential"
#     216         )
#
# File ~/galpy/galpy/potential/Potential.py:76, in check_potential_inputs_not_arrays.<locals>.func_wrapper(self, R, z, phi, t)
#      67 if (
#      68     (hasattr(R, "shape") and R.shape != () and len(R) > 1)
#      69     or (hasattr(z, "shape") and z.shape != () and len(z) > 1)
#      70     or (hasattr(phi, "shape") and phi.shape != () and len(phi) > 1)
#      71     or (hasattr(t, "shape") and t.shape != () and len(t) > 1)
#      72 ):
#      73     raise TypeError(
#      74         f"Methods in {self.__class__.__name__} do not accept array inputs. Please input scalars"
#      75     )
# ---> 76 return func(self, R, z, phi, t)
#
# File ~/galpy/galpy/potential/EllipsoidalPotential.py:138, in EllipsoidalPotential._evaluate(self, R, z, phi, t)
#     136 if not self.isNonAxi:
#     137     phi = 0.0
# --> 138 x, y, z = coords.cyl_to_rect(R, phi, z)
#     139 if numpy.isinf(R):
#     140     y = 0.0
#
# File ~/galpy/galpy/util/coords.py:1147, in cyl_to_rect(R, phi, Z)
#    1125 def cyl_to_rect(R, phi, Z):
#    1126     """
#    1127     Convert from cylindrical to rectangular coordinates
#    1128
#    (...)   1145     - 2011-02-23 - Written - Bovy (NYU)
#    1146     """
# -> 1147     return (R * numpy.cos(phi), R * numpy.sin(phi), Z)
#
# TypeError: loop of ufunc does not support argument 0 of type NoneType which has no callable cos method

# %%
aATS = actionAngleTriaxialStaeckelSingle(o.R(),o.vR(),o.vT(),o.z(),o.vz(), o.phi(), pot=tri_pot, alpha = -1, beta = -0.64, gamma = -0.36)
#aATS.JR(), aATS.Jphi(), aATS.Jz()
# Out:
# 0.23344674105930896

# %%
aATS._beta
# Out:
# -0.64

# %%
ts=numpy.linspace(0.,100.,10001)

o.integrate(ts, tri_pot)
o.plot()

# %%
def cartesian_to_ellipsoidal(x, y, z, alpha, beta, gamma):
    # using the code from galaxiesbook.org
    x = numpy.atleast_1d(x)
    y = numpy.atleast_1d(y)
    z = numpy.atleast_1d(z)
    N = len(x)
    out = numpy.empty((N, 3))
    for ii, (tx, ty, tz) in enumerate(zip(x, y, z)):
        these_coords = numpy.polynomial.polynomial.Polynomial(
            (
                beta * gamma * tx**2.0
                + alpha * gamma * ty**2.0
                + alpha * beta * tz**2.0
                - alpha * beta * gamma,
                (beta + gamma) * tx**2.0
                + (alpha + gamma) * ty**2.0
                + (alpha + beta) * tz**2.0
                - alpha * beta
                - alpha * gamma
                - beta * gamma,
                tx**2.0 + ty**2.0 + tz**2.0 - alpha - beta - gamma,
                -1.0,
            )
        ).roots()
        out[ii] = sorted(these_coords)[::-1]
    return out


def cartesian_to_ellipsoidal_vect(x, y, z, vx, vy, vz, alpha, beta, gamma):
    # using equation 4, derived from 2
    l, m, n = cartesian_to_ellipsoidal(x, y, z, alpha, beta, gamma)[0]

    # equation 2
    x2 = ((l + alpha) * (m + alpha) * (n + alpha)) / ((alpha - beta) * (alpha - gamma))
    y2 = ((l + beta) * (m + beta) * (n + beta)) / ((beta - alpha) * (beta - gamma))
    z2 = ((l + gamma) * (m + gamma) * (n + gamma)) / ((gamma - beta) * (gamma - alpha))
    
    print(y2)
    vl = (
        (vx / 2) * numpy.sqrt(max(0, x2 / ((l + alpha) ** 2)))
        + (vy / 2) * numpy.sqrt(max(0, y2 / ((l + beta) ** 2)))
        + (vz / 2) * numpy.sqrt(max(0, z2 / ((l + gamma) ** 2)))
    )

    vm = (
        (vx / 2) * numpy.sqrt(max(0, x2 / ((m + alpha) ** 2)))
        + (vy / 2) * numpy.sqrt(max(0, y2 / ((m + beta) ** 2)))
        + (vz / 2) * numpy.sqrt(max(0, z2 / ((m + gamma) ** 2)))
    )

    vn = (
        (vx / 2) * numpy.sqrt(max(0, x2 / ((n + alpha) ** 2)))
        + (vy / 2) * numpy.sqrt(max(0, y2 / ((n + beta) ** 2)))
        + (vz / 2) * numpy.sqrt(max(0, z2 / ((n + gamma) ** 2)))
    )

    return (vl, vm, vn)

def ellipsoidal_to_cartesian(l, m, n, alpha, beta, gamma):
    x = numpy.sqrt(max(0, 
        (l + alpha) * (m + alpha) * (n + alpha) / (alpha - beta) / (alpha - gamma)
    ))
    y = numpy.sqrt(max(0, 
        (l + beta) * (m + beta) * (n + beta) / (beta - alpha) / (beta - gamma)
    ))
    z = numpy.sqrt(max(0,
        (l + gamma) * (m + gamma) * (n + gamma) / (gamma - beta) / (gamma - alpha)
    ))
    return numpy.array([x, y, z]).T

# %%
print(aAS._E)
print(aATS._E)
aATS
# Out:
# -0.08688226624592563
# -0.2938989855860992

# %%
def potentialFromEllipsoidal(l, m, n, pot, alpha, beta, gamma):
    """
    Return the potential.

    Parameters
    ----------
    l : float
        Ellipsoidal lambda.
    n : float
        Ellipsoidal mu.
    m : float
        Ellipsoidal nu.
    pot : Potential object
        Potential.
    delta : float
        Focus.

    Returns
    -------
    float
        Potential at (l, m, n).

    Notes
    -----
    - 2026-06-07 - Written - Weatherall
    """
    x, y, z = ellipsoidal_to_cartesian(l, m, n, alpha, beta, gamma)
    R, phi, z = coords.rect_to_cyl(x, y, z)

    return _evaluatePotentials(pot, R, z, phi) #approproate for these types of potentials? #TODO: create helper function for triax potential

def _chi_l(l, m, n, pot):
    return (l - m) * (n - l) * pot

def _chi_m(l, m, n, pot):
    return (m - n) * (l - m) * pot

def _chi_n(l, m, n, pot):
    return (n - l) * (m - n) * pot

l_solve_here = lambda tau: (
    ((aATS._E * tau**2) - (aATS._A_l * tau) + aATS._B_l + _chi_l(tau, aATS._m, aATS._n, potentialFromEllipsoidal(tau, aATS._m, aATS._n, aATS._pot, aATS._alpha, aATS._beta, aATS._gamma)))
     #/ (2 * (tau + aATS._alpha) * (tau + aATS._beta) * (tau + aATS._gamma))
)

m_solve_here = lambda tau: (
    ((aATS._E * tau**2) - (aATS._A_m * tau) + aATS._B_m + _chi_m(aATS._l, tau, aATS._n, potentialFromEllipsoidal(aATS._l, tau, aATS._n, aATS._pot, aATS._alpha, aATS._beta, aATS._gamma)))
    #/ (2 * (tau + aATS._alpha) * (tau + aATS._beta) * (tau + aATS._gamma))
)

n_solve_here = lambda tau: (
    ((aATS._E * tau**2) - (aATS._A_n * tau) + aATS._B_n + _chi_n(aATS._l, aATS._m, tau, potentialFromEllipsoidal(aATS._l, aATS._m, tau, aATS._pot, aATS._alpha, aATS._beta, aATS._gamma)))
    #/ (2 * (tau + aATS._alpha) * (tau + aATS._beta) * (tau + aATS._gamma))
)

# %%
import matplotlib.pyplot as plt
import numpy as np
from galpy.util import coords
from galpy.potential.Potential import _evaluatePotentials

_l_input = np.linspace(-aATS._alpha, 2.3, 1000)
_m_input = np.linspace(-aATS._beta, -aATS._alpha, 1000)
_n_input = np.linspace(-aATS._gamma, -aATS._beta, 1000)

_l_results = []
_l_results_alt = []
_m_results = []
_n_results = []

for tau in _l_input:
    _l_results.append(l_solve_here(tau))
    #_l_results_alt.append(l_solve_alt(tau))

for tau in _m_input:
    _m_results.append(m_solve_here(tau))

for tau in _n_input:
    _n_results.append(n_solve_here(tau))

# %%
plt.plot(_l_input, _l_results)
#plt.hlines(0, 0.9, 2.2)
#plt.plot(_l_input, _l_results_alt)
#plt.ylim(-1, 1)

# %%
plt.plot(_m_input, _m_results)
#plt.ylim(0, 10)

# %%
plt.plot(_n_input, _n_results)
#plt.ylim(-0.1, 0.0)

# %%
print(l_solve_here(aATS._l))
print(m_solve_here(aATS._m))
print(n_solve_here(aATS._n))
# Out:
# 0.004832115672199322
# -0.0010357456876987081
# 0.00773335094445643
